# %%
import os
from utils import load_data

# %%
data = load_data('data/')
X_train, y_train, person_train = data['X_train_valid'], data['y_train_valid'], data['person_train_valid']
X_test, y_test, person_test = data['X_test'], data['y_test'], data['person_test']
person_train = person_train[:, 0]
person_test = person_test[:, 0]

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
# train data histograms
train_df = pd.DataFrame(data={'label': y_train, 'target': person_train})
train_df.hist()
plt.show()

# %%
# test data histograms
test_df = pd.DataFrame(data={'label': y_test, 'target': person_test})
test_df.hist()
plt.show()

# %%
def plot_ex(x, save_name=None):
    plt.figure(figsize=(20, 5))
    plt.imshow(x, cmap='gray')
    if save_name is not None:
        plt.savefig(fname=save_name)
    plt.show()

# %matplotlib qt
# %matplotlib inline
for i in range(10):
    plot_ex(X_train[i])

# %%
# stats
stats = pd.DataFrame()
stats["Channel"] = np.arange(X_train.shape[1])
stats["Mean"] = np.mean(X_train, axis=(-1, -3))
stats["Std"] = np.std(X_train, axis=(-1, -3))
stats["Max"] = np.max(X_train, axis=(-1, -3))
stats["Min"] = np.min(X_train, axis=(-1, -3))
print("X_train stats")
stats
# Out:
# X_train stats
#     Channel      Mean        Std        Max        Min
# 0         0  0.239599  11.242389  98.046875 -98.828125
# 1         1  0.287383  10.239766  89.208984 -94.091797
# 2         2  0.280510  10.913744  80.517578 -85.791016
# 3         3  0.277058  11.490140  80.615234 -84.863281
# 4         4  0.281874  11.208790  79.931641 -85.742188
# 5         5  0.302106  10.887567  91.650391 -90.917969
# 6         6  0.369432   8.712247  85.253906 -84.716797
# 7         7  0.353149  10.065130  82.812500 -83.349609
# 8         8  0.293090  10.692804  83.007812 -80.224609
# 9         9  0.285405  11.338118  81.445312 -81.054688
# 10       10  0.283045  10.985087  80.859375 -81.689453
# 11       11  0.326257  10.906480  88.867188 -87.451172
# 12       12  0.339394  10.111583  99.902344 -89.843750
# 13       13  0.370918  10.325750  83.203125 -79.931641
# 14       14  0.371084  10.632581  81.787109 -84.423828
# 15       15  0.377687  11.092353  80.273438 -81.835938
# 16       16  0.312366  10.994019  81.396484 -81.201172
# 17       17  0.330761  11.108176  86.035156 -85.498047
# 18       18  0.290646  10.785984  83.935547 -89.599609
# 19       19  0.338940  11.232722  82.031250 -93.994141
# 20       20  0.360754  11.155870  83.984375 -92.919922
# 21       21  0.326986  11.332241  92.919922 -97.998047
